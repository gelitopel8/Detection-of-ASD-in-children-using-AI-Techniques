# %%
# !apt-get install python-dev python-snappy
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# Package python-dev is not available, but is referred to by another package.
# This may mean that the package is missing, has been obsoleted, or
# is only available from another source
# However the following packages replace it:
#   python2-dev python2 python-dev-is-python3
#
# E: Package 'python-dev' has no installation candidate
# E: Unable to locate package python-snappy

# %%
# !pip install -q --upgrade tensorflow_data_validation
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 19.1/19.1 MB 36.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.8/14.8 MB 15.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.9/35.9 MB 7.4 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.9/99.9 kB 2.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 22.5/22.5 MB 20.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.7/89.7 kB 4.8 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.5/138.5 kB 2.6 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 152.0/152.0 kB 11.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 18.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.5/43.5 kB 2.7 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...

# %%
import pandas as pd
import numpy as np
import os
import glob
import csv

import tensorflow as tf
#import tensorflow_data_validation as tfdv
#from __future__ import print_function
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
#todos_los_archivos = [i for i in glob.glob('*.{}'.format('csv'))]
#dataset = pd.concat([pd.read_csv(f) for f in todos_los_archivos ])
#dataset.head()

# %%
dataset = pd.read_csv("DataSet.csv")
metadata = pd.read_csv("Metadata_Participants.csv")
# Out:
# <ipython-input-3-920e9107619b>:1: DtypeWarning: Columns (7) have mixed types. Specify dtype option on import or set low_memory=False.
#   dataset = pd.read_csv("DataSet.csv")

# %%
dataset
# Out:
#        Unnamed: 0  RecordingTime [ms] Time of Day [h:m:s:ms]     Trial  \
# 0               0         4677761.695           13:20:35:000  Trial001
# 1               1         4677773.919           13:20:35:012  Trial001
# 2               2         4677793.801           13:20:35:032  Trial001
# 3               3         4677813.819           13:20:35:052  Trial001
# 4               4         4677833.682           13:20:35:072  Trial001
# ...           ...                 ...                    ...       ...
# 28834       28834         1064155.056           12:18:02:220  Trial001
# 28835       28835         1064174.672           12:18:02:239  Trial001
# 28836       28836         1064189.810           12:18:02:254  Trial001
# 28837       28837         1064209.669           12:18:02:274  Trial001
# 28838       28838         1064229.526           12:18:02:294  Trial001
#
#                  Stimulus  Export Start Trial Time [ms]  \
# 0      01vnvg151201b1.avi                           0.0
# ...

# %%
metadata.head()
# Out:
#    ParticipantID Gender  Age Class  CARS Score
# 0              1      M  7.0   ASD        32.5
# 1              2      F  8.9   ASD        36.5
# 2              3      M  4.4   ASD        27.0
# 3              4      M  6.9   ASD        35.0
# 4              5      M  8.9   ASD        31.0

# %%
metadata[metadata["ParticipantID"]==1]["Class"]
dataset["Participant"]
# Out:
# 0                       50
# 1                       50
# 2                       50
# 3                       50
# 4                       50
#                ...
# 28834    Unidentified(Neg)
# 28835    Unidentified(Neg)
# 28836    Unidentified(Neg)
# 28837    Unidentified(Neg)
# 28838    Unidentified(Neg)
# Name: Participant, Length: 28839, dtype: object

# %%
dataset["Participant"].unique()
# Out:
# array([50, 43, 48, 52, 49, 51, 55, 44, 45, '45', '53', '47', '46', '42',
#        'Unidentified(Neg)'], dtype=object)

# %%
dataset_with_labels = dataset
for row in dataset_with_labels["Participant"]:
  if not row=="Unidentified(Neg)" or row == "Unidentified(Pos)":
    dataset_with_labels['LABEL'] = metadata["Class"][metadata["ParticipantID"]==int(row)].values[0]
print(dataset_with_labels["Participant"].unique())
# Out:
# [50 43 48 52 49 51 55 44 45 '45' '53' '47' '46' '42' 'Unidentified(Neg)']

# %%
dataset
# Out:
#        Unnamed: 0  RecordingTime [ms] Time of Day [h:m:s:ms]     Trial  \
# 0               0         4677761.695           13:20:35:000  Trial001
# 1               1         4677773.919           13:20:35:012  Trial001
# 2               2         4677793.801           13:20:35:032  Trial001
# 3               3         4677813.819           13:20:35:052  Trial001
# 4               4         4677833.682           13:20:35:072  Trial001
# ...           ...                 ...                    ...       ...
# 28834       28834         1064155.056           12:18:02:220  Trial001
# 28835       28835         1064174.672           12:18:02:239  Trial001
# 28836       28836         1064189.810           12:18:02:254  Trial001
# 28837       28837         1064209.669           12:18:02:274  Trial001
# 28838       28838         1064229.526           12:18:02:294  Trial001
#
#                  Stimulus  Export Start Trial Time [ms]  \
# 0      01vnvg151201b1.avi                           0.0
# ...

# %%
#dataset_with_labels.to_csv("DataSet_with_Labels.csv", index=False)
dataset_with_labels
# Out:
#        Unnamed: 0  RecordingTime [ms] Time of Day [h:m:s:ms]     Trial  \
# 0               0         4677761.695           13:20:35:000  Trial001
# 1               1         4677773.919           13:20:35:012  Trial001
# 2               2         4677793.801           13:20:35:032  Trial001
# 3               3         4677813.819           13:20:35:052  Trial001
# 4               4         4677833.682           13:20:35:072  Trial001
# ...           ...                 ...                    ...       ...
# 28834       28834         1064155.056           12:18:02:220  Trial001
# 28835       28835         1064174.672           12:18:02:239  Trial001
# 28836       28836         1064189.810           12:18:02:254  Trial001
# 28837       28837         1064209.669           12:18:02:274  Trial001
# 28838       28838         1064229.526           12:18:02:294  Trial001
#
#                  Stimulus  Export Start Trial Time [ms]  \
# 0      01vnvg151201b1.avi                           0.0
# ...

# %%
dataset_train_data , dataset_test_validation_data = train_test_split(dataset, test_size=0.2, random_state=42)
dataset_train_label , dataset_test_validation_label = train_test_split(metadata["Class"], test_size=0.2, random_state=42)
dataset_test_data , dataset_validation_data = train_test_split(dataset_test_validation_data, test_size=0.2, random_state=42)
dataset_test_label , dataset_validation_label = train_test_split(dataset_test_validation_label , test_size=0.2, random_state=42)
